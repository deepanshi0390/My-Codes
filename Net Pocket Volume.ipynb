# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Net_Volume=pd.read_csv("Net_Volume_LC3B_new.csv")
Net_Volume
# Out:
#       proLC3B-S1  proLC3B-S2  proLC3B-S3  Unnamed: 3  LC3B-S1  LC3B-S2  \
# 0         71.500      71.500      71.500         NaN   99.625   99.500
# 1         81.125      71.125      67.250         NaN   88.625  143.375
# 2         81.125      60.750      68.125         NaN   53.750  166.250
# 3         75.875      12.250      53.125         NaN  118.125   71.750
# 4         65.875      21.875      52.375         NaN  127.625   99.375
# ...          ...         ...         ...         ...      ...      ...
# 996      108.750      47.375      60.375         NaN  103.000  209.625
# 997       86.125      73.625      71.250         NaN  102.625  220.000
# 998       99.250      76.375      69.500         NaN  153.250  179.625
# 999       76.625      45.250      62.625         NaN  105.000  157.500
# 1000     113.000      30.250      74.875         NaN  100.625  172.375
#
#       LC3B-S3  Unnamed: 7  LC3B-p62-S1  LC3B-p62-S2  LC3B-p62-S3
# ...

# %%
start=0
time=[]
for i in range(1,1001):
    
    start=start+0.001
    time.append(start)
time.insert(0,0)
time[-1] #to check the last value
len(time)
# Out:
# 1001

# %%
Net_Volume['Time']=time #to create a new column named Time and append the values to the column
Net_Volume
# Out:
#       proLC3B-S1  proLC3B-S2  proLC3B-S3  Unnamed: 3  LC3B-S1  LC3B-S2  \
# 0         71.500      71.500      71.500         NaN   99.625   99.500
# 1         81.125      71.125      67.250         NaN   88.625  143.375
# 2         81.125      60.750      68.125         NaN   53.750  166.250
# 3         75.875      12.250      53.125         NaN  118.125   71.750
# 4         65.875      21.875      52.375         NaN  127.625   99.375
# ...          ...         ...         ...         ...      ...      ...
# 996      108.750      47.375      60.375         NaN  103.000  209.625
# 997       86.125      73.625      71.250         NaN  102.625  220.000
# 998       99.250      76.375      69.500         NaN  153.250  179.625
# 999       76.625      45.250      62.625         NaN  105.000  157.500
# 1000     113.000      30.250      74.875         NaN  100.625  172.375
#
#       LC3B-S3  Unnamed: 7  LC3B-p62-S1  LC3B-p62-S2  LC3B-p62-S3   Time
# ...

# %%
plt.figure(figsize=(40,30))

# plt.plot(Net_Volume['Time'],Net_Volume['proLC3B-S1'],label="CS LC3B",color='#FF7878',linewidth=8)
# plt.plot(Net_Volume['Time'],Net_Volume['proLC3B-S2'],color='#FF7878',linewidth=8)
# plt.plot(Net_Volume['Time'],Net_Volume['proLC3B-S3'],color='#FF7878',linewidth=8)

plt.plot(Net_Volume['Time'],Net_Volume['LC3B-S1'],label="Apo MB LC3B",color='#5A91FF',linewidth=8)
plt.plot(Net_Volume['Time'],Net_Volume['LC3B-S2'],color='#5A91FF',linewidth=8)
plt.plot(Net_Volume['Time'],Net_Volume['LC3B-S3'],color='#5A91FF',linewidth=8)

plt.plot(Net_Volume['Time'],Net_Volume['LC3B-p62-S1'],label="MB LC3B LIR",color='#7DA629',linewidth=8)
plt.plot(Net_Volume['Time'],Net_Volume['LC3B-p62-S2'],color='#7DA629',linewidth=8)
plt.plot(Net_Volume['Time'],Net_Volume['LC3B-p62-S3'],color='#7DA629',linewidth=8)


plt.xlabel("Time (µs)", size=120)
plt.ylabel("Net Pocket Volume (Å\u00B3)", size=120)
plt.rcParams.update({'font.size': 120})

label_size = 100
plt.rcParams['xtick.labelsize'] = label_size
plt.rcParams['ytick.labelsize'] = label_size

plt.rcParams['xtick.bottom'] = True
plt.rcParams['xtick.top'] = True
plt.rcParams['xtick.major.size'] = 30
plt.rcParams['xtick.major.width'] = 10
plt.rcParams['xtick.direction'] = 'in'

plt.rcParams['ytick.left'] = True
plt.rcParams['ytick.right'] = True
plt.rcParams['ytick.major.size'] = 30
plt.rcParams['ytick.major.width'] = 10
plt.rcParams['ytick.direction'] = 'in'

plt.rcParams["figure.autolayout"] = True
plt.rcParams["axes.edgecolor"] = "black"
plt.rcParams["axes.linewidth"] = 8

# plt.xlim([-5,250])
# plt.ylim([0, 0.10])


plt.legend(loc='upper right', prop={'size': 70})

# plt.savefig("LC3B-net-pocket-volume.png",dpi=650,bbox_inches='tight')

# %%
plt.figure(figsize=(40,30))

sns.kdeplot(data=Net_Volume['proLC3B-S1'],fill=True,alpha=0.5,label="CS LC3B",color='#FF7878',linewidth=8)
sns.kdeplot(data=Net_Volume['proLC3B-S2'],fill=True,alpha=0.5,color='#FF7878',linewidth=8)
sns.kdeplot(data=Net_Volume['proLC3B-S3'],fill=True,alpha=0.5,color='#FF7878',linewidth=8)

sns.kdeplot(data=Net_Volume['LC3B-S1'],fill=True,alpha=0.5,label="Apo MB LC3B",color='#5A91FF',linewidth=8)
sns.kdeplot(data=Net_Volume['LC3B-S2'],fill=True,alpha=0.5,color='#5A91FF',linewidth=8)
sns.kdeplot(data=Net_Volume['LC3B-S3'],fill=True,alpha=0.5,color='#5A91FF',linewidth=8)

sns.kdeplot(data=Net_Volume['LC3B-p62-S1'],fill=True,alpha=0.5,label="LIR MB LC3B",color='#7DA629',linewidth=8)
sns.kdeplot(data=Net_Volume['LC3B-p62-S2'],fill=True,alpha=0.5,color='#7DA629',linewidth=8)
sns.kdeplot(data=Net_Volume['LC3B-p62-S3'],fill=True,alpha=0.5,color='#7DA629',linewidth=8)

plt.xlabel("Net Pocket Volume (Å\u00B3)", size=140)
plt.ylabel("Distribution", size=140)
plt.rcParams.update({'font.size': 120})

label_size = 100
plt.rcParams['xtick.labelsize'] = label_size
plt.rcParams['ytick.labelsize'] = label_size

plt.rcParams['xtick.bottom'] = True
plt.rcParams['xtick.top'] = True
plt.rcParams['xtick.major.size'] = 30
plt.rcParams['xtick.major.width'] = 10
plt.rcParams['xtick.direction'] = 'in'

plt.rcParams['ytick.left'] = True
plt.rcParams['ytick.right'] = True
plt.rcParams['ytick.major.size'] = 30
plt.rcParams['ytick.major.width'] = 10
plt.rcParams['ytick.direction'] = 'in'

plt.rcParams["figure.autolayout"] = True
plt.rcParams["axes.edgecolor"] = "black"
plt.rcParams["axes.linewidth"] = 8

# plt.xlim([-5,250])
# plt.ylim([0, 0.10])


plt.legend(loc='upper right', prop={'size':90})

plt.savefig("LC3B-net-pocket-volume_distribution.png",dpi=650,bbox_inches='tight')

# %%
Net_Volume_II=pd.read_csv("Net_Volume_LC3B_17_01_25.csv")
Net_Volume_II
# Out:
#       pro-LC3B_S1  pro-LC3B_S2  pro-LC3B_S3  Unnamed: 3  apo-LC3B_S1  \
# 0           9.375        9.375        9.375         NaN        8.375
# 1           8.750        1.125        8.625         NaN        4.250
# 2          18.750        7.125       13.000         NaN        6.000
# 3           8.750        1.750        3.375         NaN        8.375
# 4           4.750        3.250        4.125         NaN       56.125
# ...           ...          ...          ...         ...          ...
# 1997       99.625       43.500       52.250         NaN       66.500
# 1998       80.625       66.875       66.625         NaN       64.250
# 1999       82.750       49.500       63.875         NaN      106.625
# 2000       66.375       30.125       51.250         NaN       80.250
# 2001      105.125       19.375       68.875         NaN       76.125
#
#       apo-LC3B_S2  apo-LC3B_S3  Unnamed: 7  LIR-LC3B_S1  LIR-LC3B_S2  \
# ...

# %%
start=0
time=[]
for i in range(1,2002):
    
    start=start+0.001
    time.append(start)
time.insert(0,0)
time[-1] #to check the last value
len(time)
# Out:
# 2002

# %%
Net_Volume_II['Time']=time #to create a new column named Time and append the values to the column
Net_Volume_II
# Out:
#       pro-LC3B_S1  pro-LC3B_S2  pro-LC3B_S3  Unnamed: 3  apo-LC3B_S1  \
# 0           9.375        9.375        9.375         NaN        8.375
# 1           8.750        1.125        8.625         NaN        4.250
# 2          18.750        7.125       13.000         NaN        6.000
# 3           8.750        1.750        3.375         NaN        8.375
# 4           4.750        3.250        4.125         NaN       56.125
# ...           ...          ...          ...         ...          ...
# 1997       99.625       43.500       52.250         NaN       66.500
# 1998       80.625       66.875       66.625         NaN       64.250
# 1999       82.750       49.500       63.875         NaN      106.625
# 2000       66.375       30.125       51.250         NaN       80.250
# 2001      105.125       19.375       68.875         NaN       76.125
#
#       apo-LC3B_S2  apo-LC3B_S3  Unnamed: 7  LIR-LC3B_S1  LIR-LC3B_S2  \
# ...

# %%
plt.figure(figsize=(40,30))

sns.kdeplot(data=Net_Volume_II['pro-LC3B_S1'],fill=True,alpha=0.5,label="CS LC3B",color='#FF7878',linewidth=8)
sns.kdeplot(data=Net_Volume_II['pro-LC3B_S2'],fill=True,alpha=0.5,color='#FF7878',linewidth=8)
sns.kdeplot(data=Net_Volume_II['pro-LC3B_S3'],fill=True,alpha=0.5,color='#FF7878',linewidth=8)

sns.kdeplot(data=Net_Volume_II['apo-LC3B_S1'],fill=True,alpha=0.5,label="Apo LC3B-II",color='#5A91FF',linewidth=8)
sns.kdeplot(data=Net_Volume_II['apo-LC3B_S2'],fill=True,alpha=0.5,color='#5A91FF',linewidth=8)
sns.kdeplot(data=Net_Volume_II['apo-LC3B_S3'],fill=True,alpha=0.5,color='#5A91FF',linewidth=8)

sns.kdeplot(data=Net_Volume_II['LIR-LC3B_S1'],fill=True,alpha=0.5,label="LIR LC3B-II",color='#7DA629',linewidth=8)
sns.kdeplot(data=Net_Volume_II['LIR-LC3B_S2'],fill=True,alpha=0.5,color='#7DA629',linewidth=8)
sns.kdeplot(data=Net_Volume_II['LIR-LC3B_S3'],fill=True,alpha=0.5,color='#7DA629',linewidth=8)

plt.xlabel("Net Pocket Volume (Å\u00B3)", size=140)
plt.ylabel("Distribution", size=140)
plt.rcParams.update({'font.size': 120})

label_size = 100
plt.rcParams['xtick.labelsize'] = label_size
plt.rcParams['ytick.labelsize'] = label_size

plt.rcParams['xtick.bottom'] = True
plt.rcParams['xtick.top'] = True
plt.rcParams['xtick.major.size'] = 30
plt.rcParams['xtick.major.width'] = 10
plt.rcParams['xtick.direction'] = 'in'

plt.rcParams['ytick.left'] = True
plt.rcParams['ytick.right'] = True
plt.rcParams['ytick.major.size'] = 30
plt.rcParams['ytick.major.width'] = 10
plt.rcParams['ytick.direction'] = 'in'

plt.rcParams["figure.autolayout"] = True
plt.rcParams["axes.edgecolor"] = "black"
plt.rcParams["axes.linewidth"] = 8

# plt.xlim([-5,250])
# plt.ylim([0, 0.10])


plt.legend(loc='upper right', prop={'size':90})

plt.savefig("LC3B-net-pocket-volume_distribution_17_01_25.png",dpi=650,bbox_inches='tight')

# %%
plt.figure(figsize=(50,25))

sns.kdeplot(data=Net_Volume_II['LIR-LC3B_S1'],fill=True,alpha=0.5,label="p62 LIR LC3B-II",color='#7DA629',linewidth=8)
sns.kdeplot(data=Net_Volume_II['LIR-LC3B_S2'],fill=True,alpha=0.5,color='#7DA629',linewidth=8)
sns.kdeplot(data=Net_Volume_II['LIR-LC3B_S3'],fill=True,alpha=0.5,color='#7DA629',linewidth=8)

sns.kdeplot(data=Net_Volume_II['LC3B_OPTN'],fill=True,alpha=0.5,label="OPTN LIR LC3B-II",color='#F26344',linewidth=8)
sns.kdeplot(data=Net_Volume_II['LC3B_NBR1'],fill=True,alpha=0.5,label="NBR1 LIR LC3B-II",color='#DEA10D',linewidth=8)


plt.xlabel("Net Pocket Volume (Å³)", size=100)
plt.ylabel("Distribution", size=100)
plt.rcParams.update({'font.size': 120})

label_size = 100
plt.rcParams['xtick.labelsize'] = label_size
plt.rcParams['ytick.labelsize'] = label_size

plt.rcParams['xtick.bottom'] = True
plt.rcParams['xtick.top'] = True
plt.rcParams['xtick.major.size'] = 30
plt.rcParams['xtick.major.width'] = 10
plt.rcParams['xtick.direction'] = 'in'

plt.rcParams['ytick.left'] = True
plt.rcParams['ytick.right'] = True
plt.rcParams['ytick.major.size'] = 30
plt.rcParams['ytick.major.width'] = 10
plt.rcParams['ytick.direction'] = 'in'

plt.rcParams["figure.autolayout"] = True
plt.rcParams["axes.edgecolor"] = "black"
plt.rcParams["axes.linewidth"] = 8

plt.xlim([0, 300])
plt.ylim([0, 0.025])



plt.legend(loc='upper right', prop={'size': 80})

plt.savefig("LC3B-NBR1_OPTN-Bound-Net-volume.png",dpi=650,bbox_inches='tight')
